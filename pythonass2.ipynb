# %%
#I.List creation
age_list=[24,25,26,27,28,29]

# %%
name_list=["Sreeja","Anit","Siniya","Sarath","Indrajith"]

# %%
#II.List operations
#a.append
name_list.append("Yazhini")

# %%
print(name_list)
# Out:
# ['Sreeja', 'Anit', 'Siniya', 'Sarath', 'Indrajith', 'Yazhini']

# %%
#b.insert

age_list.insert(2,30)

# %%
age_list
# Out:
# [24, 25, 30, 30, 30, 26, 27, 28, 29, 30, 26]

# %%
#c.remove

name_list.remove("Yazhini")

# %%
name_list
# Out:
# ['Sreeja', 'Anit', 'Siniya', 'Sarath', 'Indrajith']

# %%
#d.pop

age_list.pop(-1)
# Out:
# 26

# %%
#e.extend

age_list.extend([29,30,26])

# %%
age_list
# Out:
# [24, 25, 30, 30, 30, 26, 27, 28, 29, 30, 29, 30, 26]

# %%
#f.descent

age_list.sort(reverse=True)

# %%
#g.Max ,Min age

print(max(age_list))
# Out:
# 30

# %%
print(min(age_list))
# Out:
# 24

# %%
print(sum(age_list))
# Out:
# 364

# %%
#III.Accessing List Elements

# %%
print(name_list[0])
# Out:
# Sreeja

# %%
print(name_list[-1])
# Out:
# Indrajith

# %%
print(name_list[2:5])
# Out:
# ['Siniya', 'Sarath', 'Indrajith']

# %%
print(name_list[::-1])
# Out:
# ['Indrajith', 'Sarath', 'Siniya', 'Anit', 'Sreeja']

# %%
#IV.Dictionary

student_marks={"Abhi":85,"Bhavin":78,"Meera":92,"Anoop":90,"Sreeja":86}

# %%
print(student_marks["Meera"])
# Out:
# 92

# %%
student_marks.update({"Janani":80})

# %%
student_marks
# Out:
# {'Abhi': 85,
#  'Bhavin': 78,
#  'Meera': 92,
#  'Anoop': 90,
#  'Sreeja': 86,
#  'vineeth': 74,
#  'Janani': 80}

# %%
student_marks["Abhi"]=82

# %%
student_marks
# Out:
# {'Abhi': 82,
#  'Bhavin': 78,
#  'Meera': 92,
#  'Anoop': 90,
#  'Sreeja': 86,
#  'vineeth': 74,
#  'Janani': 80}

# %%
print(student_marks.keys())
# Out:
# dict_keys(['Abhi', 'Bhavin', 'Meera', 'Anoop', 'Sreeja', 'vineeth', 'Janani'])

# %%
print(student_marks.values())
# Out:
# dict_values([82, 78, 92, 90, 86, 74, 80])

# %%
print(student_marks.items())
# Out:
# dict_items([('Abhi', 82), ('Bhavin', 78), ('Meera', 92), ('Anoop', 90), ('Sreeja', 86), ('vineeth', 74), ('Janani', 80)])

# %%
#V Sets

my_set={"a","e","i","o","u","a","a","i"}

# %%
my_set
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
#In Sets the duplication of values not allowed,if we enter the same value inside the set only one value show in the set.

# %%
my_set[4]="s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 my_set[4]="s"
#
# TypeError: 'set' object does not support item assignment

# %%
#The error because SET has no index and order,not possible to add element like this

# %%
set1={1,3,5,7,9}
set2={2,3,5,8,10}

# %%
set3=set1.union(set2)

# %%
set3
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
#VI Operators & Conditional Statements

score=int(input("enter your score in between 0 and 10:  "))

if (score > 7):
    print("Above Average")
    print("Excellent! Keep it up.")
elif score>=4 and score<=7:
          print("Average")
          print("Good effort,keep practicing ,there's room for improvement.")
else:
    print("Below Average")
    print("Need to improve your performance ,consistent practice will lead to better result")
# Out:
# enter your score in between 0 and 10:   2
# Below Average
# Need to improve your performance ,consistent practice will lead to better result
