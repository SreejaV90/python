# %%
# String Concatenation:
s1="Hello"
name=input("enter your name:")
# Out:
# enter your name: sreeja

# %%
concat_str=s1+" "+name

# %%
print(concat_str)
# Out:
# Hello sreeja

# %%
s3="welcome to python programming"

# %%
final_str=concat_str+" "+s3

# %%
print( final_str)
# Out:
# Hello sreeja welcome to python programming

# %%
#2. String Slicing and Indexing:
#first character
print(final_str[0])
# Out:
# H

# %%
#Print the last character of the string.

print(final_str[-1])
# Out:
# g

# %%
#Print the first 5 characters of the string

print(final_str[:5])
# Out:
# Hello

# %%
#Print the last 11 characters of the string.

print(final_str[-11:])
# Out:
# programming

# %%
#Print the string in reverse.

print(final_str[::-1])
# Out:
# gnimmargorp nohtyp ot emoclew ajeers olleH

# %%
#Use slicing and print the word “Python” from the existing string.

print(final_str[24:31])
# Out:
# python

# %%
#3.String Methods:
strM = "Python beginner tutorial"

# %%
#Convert the sentence to uppercase.

strM.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %%
#Convert the sentence to lowercase.

strM.lower()
# Out:
# 'python beginner tutorial'

# %%
#Use Capitalize and return the sentence to the original input form.

strM.capitalize()
# Out:
# 'Python beginner tutorial'

# %%
#Count the total number of occurrences of character ‘t’ in the string

strM.count("t")
# Out:
# 3

# %%
#Replace all occurrences of “Python” with “Machine Learning” in the input string strM = “Python beginner tutorial”

new_srtM=strM.replace("Python","Machine Learning")

# %%
print(new_srtM)
# Out:
# Machine Learning beginner tutorial

# %%
#Tuples (Creation, Modification and Access) :

t1=(10,20,30)

# %%
t2=(40,50,60)

# %%
#a. Concatenate the two tuples and store it in “t_combine”

t_combain=t1+t2

# %%
print(t_combain)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
#b. Repeat the elements of “t_combine” 3 times

print(t_combain*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
#c.Access the 3rd element from “t_combine"

print(t_combain[2])
# Out:
# 30

# %%
#d.Access the first three elements from “t_combine”

print(t_combain[:3])
# Out:
# (10, 20, 30)

# %%
#e. Access the last three elements from “t_combine”

print(t_combain[-3:])
# Out:
# (40, 50, 60)
